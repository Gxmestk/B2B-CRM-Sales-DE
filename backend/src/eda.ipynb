# %%
import pandas

# Load the csv files

data_dictionary = pandas.read_csv(r"..\data\original_data\data_dictionary.csv")
products = pandas.read_csv(r"..\data\original_data\products.csv")
sales_pipeline = pandas.read_csv(r"..\data\original_data\sales_pipeline.csv")
sale_teams = pandas.read_csv(r"..\data\original_data\sales_teams.csv")
accounts = pandas.read_csv(r"..\data\original_data\accounts.csv")

# %%
data_dictionary
# Out:
#              Table             Field  \
# 0         accounts           account
# 1         accounts            sector
# 2         accounts  year_established
# 3         accounts           revenue
# 4         accounts         employees
# 5         accounts   office_location
# 6         accounts     subsidiary_of
# 7         products           product
# 8         products            series
# 9         products       sales_price
# 10     sales_teams       sales_agent
# 11     sales_teams           manager
# 12     sales_teams   regional_office
# 13  sales_pipeline    opportunity_id
# 14  sales_pipeline       sales_agent
# 15  sales_pipeline           product
# 16  sales_pipeline           account
# 17  sales_pipeline        deal_stage
# 18  sales_pipeline       engage_date
# 19  sales_pipeline        close_date
# 20  sales_pipeline       close_value
#
#                                           Description
# 0                                        Company name
# ...

# %%
dfs = [products, sales_pipeline, sale_teams, accounts]
names = ["products", "sales_pipeline", "sale_teams", "accounts"]

for i in range(len(dfs)):
    print("\033[32m" + names[i] + "\033[0m")
    dfs[i].info()
    display(dfs[i].describe(include='all'))
# Out:
# products
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product      7 non-null      object
#  1   series       7 non-null      object
#  2   sales_price  7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes
#           product series   sales_price
# count           7      7      7.000000
# unique          7      3           NaN
# top     GTX Basic    GTX           NaN
# freq            1      4           NaN
# mean          NaN    NaN   6023.571429
# std           NaN    NaN   9388.428070
# min           NaN    NaN     55.000000
# 25%           NaN    NaN    823.000000
# 50%           NaN    NaN   3393.000000
# 75%           NaN    NaN   5151.500000
# max           NaN    NaN  26768.000000
# sales_pipeline
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8800 entries, 0 to 8799
# ...

# %% [markdown]
# ![dbml_erd.svg](..\data\original_data\dbml_erd.svg)

# %%
#show row that has a null value in the account column of the sales_pipeline dataframe
no_acc_transac = sales_pipeline[sales_pipeline['account'].isnull()]

# %%
len(no_acc_transac.sales_agent.unique())
# Out:
# 27

# %%
sales_pipeline.deal_stage.unique()
# Out:
# array(['Won', 'Engaging', 'Lost', 'Prospecting'], dtype=object)

# %%
no_acc_transac.deal_stage.unique()
# Out:
# array(['Engaging', 'Prospecting'], dtype=object)

# %%
sales_pipeline.account[sales_pipeline.deal_stage == "Prospecting"].value_counts(dropna=False)
# Out:
# account
# NaN            337
# Plusstrip        5
# Donquadtech      5
# Faxquote         5
# Plussunin        5
#               ...
# Toughzap         1
# Donware          1
# Funholding       1
# Scottech         1
# Golddex          1
# Name: count, Length: 74, dtype: int64

# %%
sales_pipeline.account[sales_pipeline.deal_stage == "Engaging"].value_counts(dropna=False)
# Out:
# account
# NaN            1088
# Betasoloin       12
# Zoomit           10
# Inity            10
# Iselectrics      10
#                ...
# Fasehatice        2
# Yearin            2
# Ron-tech          2
# dambase           1
# Doncon            1
# Name: count, Length: 86, dtype: int64

# %%
no_acc_transac[no_acc_transac['sales_agent'] == 'James Ascencio']
# Out:
#      opportunity_id     sales_agent         product account deal_stage  \
# 9          HAXMC4IX  James Ascencio     MG Advanced     NaN   Engaging
# 159        JUCNIG4H  James Ascencio       GTX Basic     NaN   Engaging
# 174        IBEUTCSW  James Ascencio     MG Advanced     NaN   Engaging
# 390        QR2BDRAI  James Ascencio     MG Advanced     NaN   Engaging
# 822        5BXUKFPR  James Ascencio    GTX Plus Pro     NaN   Engaging
# 913        KM1D04JS  James Ascencio  GTX Plus Basic     NaN   Engaging
# 1088       X1D1HYMM  James Ascencio    GTX Plus Pro     NaN   Engaging
# 1175       JSZZN48S  James Ascencio    GTX Plus Pro     NaN   Engaging
# 1364       9A4H9IAC  James Ascencio  GTX Plus Basic     NaN   Engaging
# 1419       ZRYPU2QW  James Ascencio     MG Advanced     NaN   Engaging
# 1435       1B27CZ2M  James Ascencio    GTX Plus Pro     NaN   Engaging
# 1449       ILR33OAV  James Ascencio     MG Advanced     NaN   Engaging
# ...

# %%
sales_pipeline[(sales_pipeline['sales_agent'] == 'James Ascencio') & (sales_pipeline['product'] == 'MG Advanced')]
# Out:
#      opportunity_id     sales_agent      product         account deal_stage  \
# 9          HAXMC4IX  James Ascencio  MG Advanced             NaN   Engaging
# 174        IBEUTCSW  James Ascencio  MG Advanced             NaN   Engaging
# 390        QR2BDRAI  James Ascencio  MG Advanced             NaN   Engaging
# 490        VKT0UN11  James Ascencio  MG Advanced         Codehow   Engaging
# 914        RNUH1SI8  James Ascencio  MG Advanced        Kan-code        Won
# 1149       ZI1MPYF3  James Ascencio  MG Advanced  Dalttechnology        Won
# 1281       JA0D4V57  James Ascencio  MG Advanced   Y-corporation        Won
# 1419       ZRYPU2QW  James Ascencio  MG Advanced             NaN   Engaging
# 1449       ILR33OAV  James Ascencio  MG Advanced             NaN   Engaging
# 1836       XR57MBVC  James Ascencio  MG Advanced          Finjob        Won
# 2278       O08NQM1J  James Ascencio  MG Advanced          Cheers       Lost
# ...

# %%
no_acc_transac[no_acc_transac['deal_stage'] == 'Engaging']
# Out:
#      opportunity_id       sales_agent         product account deal_stage  \
# 9          HAXMC4IX    James Ascencio     MG Advanced     NaN   Engaging
# 42         EG7OFLFR     Kami Bicknell       GTX Basic     NaN   Engaging
# 44         OLVI7L8M      Cassey Cress          GTXPro     NaN   Engaging
# 56         F5U1ACDD     Kami Bicknell  GTX Plus Basic     NaN   Engaging
# 60         ZZY4516R     Hayden Neloms     MG Advanced     NaN   Engaging
# ...             ...               ...             ...     ...        ...
# 8271       T6MPH7JC  Violet Mclelland      MG Special     NaN   Engaging
# 8277       NGTVHTFH         Boris Faz          GTXPro     NaN   Engaging
# 8285       HCQK8NQ8    Wilburn Farren  GTX Plus Basic     NaN   Engaging
# 8286       RDHTQLNI      Cassey Cress    GTX Plus Pro     NaN   Engaging
# 8290       DB801ISB      Elease Gluck      MG Special     NaN   Engaging
#
#      engage_date close_date  close_value
# 9     2016-11-03        NaN          NaN
# ...

# %%
no_acc_transac[no_acc_transac.close_date.notnull()]
# Out:
# Empty DataFrame
# Columns: [opportunity_id, sales_agent, product, account, deal_stage, engage_date, close_date, close_value]
# Index: []

# %%
no_acc_transac[no_acc_transac['deal_stage'] == 'Prospecting']
# Out:
#      opportunity_id        sales_agent      product account   deal_stage  \
# 8301       3LCLVRVV      Anna Snelling    GTX Basic     NaN  Prospecting
# 8302       YIU1B39V      Anna Snelling    GTX Basic     NaN  Prospecting
# 8303       8E0VRCLW      Anna Snelling    GTX Basic     NaN  Prospecting
# 8304       G99CS23F      Anna Snelling    GTX Basic     NaN  Prospecting
# 8305       XRJ54GNR      Anna Snelling    GTX Basic     NaN  Prospecting
# ...             ...                ...          ...     ...          ...
# 8795       9MIWFW5J  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8798       18IUIUK0  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand  MG Advanced     NaN  Prospecting
#
#      engage_date close_date  close_value
# 8301         NaN        NaN          NaN
# ...

# %% [markdown]
# - known-company stale engaging  after x day
# - known-company stale prospecting  after y day
# - unknown-company stale engaging after i day
# - unknown-company stale prospecting after j day
